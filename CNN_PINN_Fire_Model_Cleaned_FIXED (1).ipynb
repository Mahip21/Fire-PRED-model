# %%
# === IMPORTS ===
import torch
import torch.nn as nn
import torch.autograd as autograd
import pandas as pd
import numpy as np
import libarchive
import pydot
import cartopy
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
import joblib
import warnings
import pickle
import io
import os
from PIL import Image
import torchvision.transforms as transforms
warnings.filterwarnings("ignore")

# %%
# === DEFINE CNN MODEL CLASS ===
class FireFeatureCNN(nn.Module):
    def __init__(self):
        super(FireFeatureCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(), nn.AdaptiveAvgPool2d((1, 1))
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64, 4)
        )

# %%
def forward(self, x):
        x = self.features(x)
        return self.classifier(x)

# %%
# === LOAD DATASET ===
df = pd.read_excel(r'/content/PT-FireSprd_L2_FireBehavior_FULL_set.ods', engine="odf")
df = df.dropna(subset=["ros_p,N,12,6", "Longitude", "Latitude"])
df = df.rename(columns={"ros_p,N,12,6": "spread_rate", "Longitude": "x", "Latitude": "y"})

# %%
scaler = MinMaxScaler()
df[['x', 'y']] = scaler.fit_transform(df[['x', 'y']])

# %%
# === LOAD CNN MODEL ===
class CustomUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if name == 'FireFeatureCNN':
            return FireFeatureCNN
        return super().find_class(module, name)

# %%
try:
    with open(r'/content/fire_model_full.pth', 'rb') as f:
        cnn_model = CustomUnpickler(f).load()
    print("Model loaded with CustomUnpickler")
except Exception as e1:
    print(f"First loading attempt failed: {e1}")
    try:
        temp_model = FireFeatureCNN()
        state_dict = torch.load(r'/content/fire_model_full.pth', map_location="cpu")
        if isinstance(state_dict, dict) and 'state_dict' in state_dict:
            state_dict = state_dict['state_dict']
        elif not all(isinstance(k, str) for k in state_dict.keys()):
            state_dict = state_dict.state_dict()
        temp_model.load_state_dict(state_dict)
        cnn_model = temp_model
        print("Model loaded via state_dict")
    except Exception as e2:
        print(f"Second loading attempt failed: {e2}")
        cnn_model = FireFeatureCNN()
        def get_dummy_cnn_features(lon, lat):
            import hashlib
            seed = hashlib.md5(f"{lon}_{lat}".encode()).hexdigest()
            seed_val = int(seed[:8], 16) / (2**32)
            np.random.seed(int(seed_val * 1000000))
            return np.random.rand(4).tolist()
        def get_actual_cnn_features(image_path, model, transform, device='cpu'):
            import re
            try:
                matches = re.search(r'lon_(.+)_lat_(.+)\.jpg', image_path)
                if matches:
                    lon, lat = float(matches.group(1)), float(matches.group(2))
                    return get_dummy_cnn_features(lon, lat)
            except:
                pass
            return np.random.rand(4).tolist()
        print("Using dummy CNN feature extraction")
# Out:
# First loading attempt failed: A load persistent id instruction was encountered,
# but no persistent_load function was specified.
# Second loading attempt failed: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL __main__.FireFeatureCNN was not an allowed global by default. Please use `torch.serialization.add_safe_globals([FireFeatureCNN])` or the `torch.serialization.safe_globals([FireFeatureCNN])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# Using dummy CNN feature extraction

# %%
cnn_model.eval()
# Out:
# FireFeatureCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=64, out_features=4, bias=True)
#   )
# )

# %%
# === IMAGE PREPROCESSING ===
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
def get_actual_cnn_features(image_path, model, transform, device='cpu'):
    model.eval()
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0).to(device)
    with torch.no_grad():
        output = model(image).cpu().numpy()[0]
    return output.tolist()

# %%
def get_image_path(lon, lat):
    return f"/content/images/lon_{lon:.6f}_lat_{lat:.6f}.jpg"

# %%
def get_slope_and_elevation(lon, lat, tif_path):
    import rasterio
    with rasterio.open(tif_path) as src:
        elev = src.read(1)
        res_x, res_y = src.res
        dy, dx = np.gradient(elev, res_y, res_x)
        slope = np.sqrt(dx**2 + dy**2)
        try:
            row, col = src.index(lon, lat)
            if 0 <= row < elev.shape[0] and 0 <= col < elev.shape[1]:
                return float(slope[row, col]), float(elev[row, col])
        except Exception as e:
            print(f"Error for coordinates ({lon}, {lat}): {e}")
    return 0.1, 100.0

# %%
X_data, y_data = [], []

# %%
for idx, row in df.iterrows():
    try:
        img_path = get_image_path(row['x'], row['y'])
        try:
            cnn_out = get_actual_cnn_features(img_path, cnn_model, transform)
        except:
            cnn_out = np.random.rand(4).tolist()

        slope, elev = get_slope_and_elevation(row['x'], row['y'], r'/TIFF_input.zip')

        # Check for valid values before appending
        if cnn_out is not None and len(cnn_out) == 4 and slope is not None and elev is not None:
            X_data.append([row['x'], row['y'], slope, elev] + cnn_out)
            y_data.append(row['spread_rate'])

        if idx % 100 == 0:
            print(f"Processed {idx} rows...")

    except Exception as e:
        print(f"Error at row {idx}: {e}")
        continue

print("X_data length:", len(X_data))  # Debug print to verify non-empty input
# Out:
# Error at row 0: No module named 'rasterio'
# Error at row 1: No module named 'rasterio'
# Error at row 2: No module named 'rasterio'
# Error at row 3: No module named 'rasterio'
# Error at row 4: No module named 'rasterio'
# Error at row 5: No module named 'rasterio'
# Error at row 6: No module named 'rasterio'
# Error at row 7: No module named 'rasterio'
# Error at row 8: No module named 'rasterio'
# Error at row 9: No module named 'rasterio'
# Error at row 10: No module named 'rasterio'
# Error at row 11: No module named 'rasterio'
# Error at row 12: No module named 'rasterio'
# Error at row 13: No module named 'rasterio'
# Error at row 14: No module named 'rasterio'
# Error at row 15: No module named 'rasterio'
# Error at row 16: No module named 'rasterio'
# Error at row 17: No module named 'rasterio'
# Error at row 18: No module named 'rasterio'
# Error at row 19: No module named 'rasterio'
# Error at row 20: No module named 'rasterio'
# Error at row 21: No module named 'rasterio'
# Error at row 22: No module named 'rasterio'
# Error at row 23: No module named 'rasterio'
# Error at row 24: No module named 'rasterio'
# Error at row 25: No module named 'rasterio'
# Error at row 26: No module named 'rasterio'
# Error at row 27: No module named 'rasterio'
# Error at row 28: No module named 'rasterio'
# Error at row 29: No module named 'rasterio'
# Error at row 30: No module named 'rasterio'
# Error at row 31: No module named 'rasterio'
# Error at row 32: No module named 'rasterio'
# Error at row 33: No module named 'rasterio'
# Error at row 34: No module named 'rasterio'
# Error at row 35: No module named 'rasterio'
# Error at row 36: No module named 'rasterio'
# Error at row 37: No module named 'rasterio'
# Error at row 38: No module named 'rasterio'
# Error at row 39: No module named 'rasterio'
# Error at row 40: No module named 'rasterio'
# Error at row 41: No module named 'rasterio'
# Error at row 42: No module named 'rasterio'
# Error at row 43: No module named 'rasterio'
# Error at row 44: No module named 'rasterio'
# Error at row 45: No module named 'rasterio'
# Error at row 46: No module named 'rasterio'
# Error at row 47: No module named 'rasterio'
# Error at row 48: No module named 'rasterio'
# Error at row 49: No module named 'rasterio'
# Error at row 50: No module named 'rasterio'
# Error at row 51: No module named 'rasterio'
# Error at row 52: No module named 'rasterio'
# Error at row 53: No module named 'rasterio'
# Error at row 54: No module named 'rasterio'
# Error at row 55: No module named 'rasterio'
# Error at row 56: No module named 'rasterio'
# Error at row 57: No module named 'rasterio'
# Error at row 58: No module named 'rasterio'
# Error at row 59: No module named 'rasterio'
# Error at row 60: No module named 'rasterio'
# Error at row 61: No module named 'rasterio'
# Error at row 62: No module named 'rasterio'
# Error at row 63: No module named 'rasterio'
# Error at row 64: No module named 'rasterio'
# Error at row 65: No module named 'rasterio'
# Error at row 66: No module named 'rasterio'
# Error at row 67: No module named 'rasterio'
# Error at row 68: No module named 'rasterio'
# Error at row 69: No module named 'rasterio'
# Error at row 70: No module named 'rasterio'
# Error at row 71: No module named 'rasterio'
# Error at row 72: No module named 'rasterio'
# Error at row 73: No module named 'rasterio'
# Error at row 74: No module named 'rasterio'
# Error at row 75: No module named 'rasterio'
# Error at row 76: No module named 'rasterio'
# Error at row 77: No module named 'rasterio'
# Error at row 78: No module named 'rasterio'
# Error at row 79: No module named 'rasterio'
# Error at row 80: No module named 'rasterio'
# Error at row 81: No module named 'rasterio'
# Error at row 82: No module named 'rasterio'
# Error at row 83: No module named 'rasterio'
# Error at row 84: No module named 'rasterio'
# Error at row 85: No module named 'rasterio'
# Error at row 86: No module named 'rasterio'
# Error at row 87: No module named 'rasterio'
# Error at row 88: No module named 'rasterio'
# Error at row 89: No module named 'rasterio'
# Error at row 90: No module named 'rasterio'
# Error at row 91: No module named 'rasterio'
# Error at row 92: No module named 'rasterio'
# Error at row 93: No module named 'rasterio'
# Error at row 94: No module named 'rasterio'
# Error at row 95: No module named 'rasterio'
# Error at row 96: No module named 'rasterio'
# Error at row 97: No module named 'rasterio'
# Error at row 98: No module named 'rasterio'
# Error at row 99: No module named 'rasterio'
# Error at row 100: No module named 'rasterio'
# Error at row 101: No module named 'rasterio'
# Error at row 102: No module named 'rasterio'
# Error at row 103: No module named 'rasterio'
# Error at row 104: No module named 'rasterio'
# Error at row 105: No module named 'rasterio'
# Error at row 106: No module named 'rasterio'
# Error at row 107: No module named 'rasterio'
# Error at row 108: No module named 'rasterio'
# Error at row 109: No module named 'rasterio'
# Error at row 110: No module named 'rasterio'
# Error at row 111: No module named 'rasterio'
# Error at row 112: No module named 'rasterio'
# Error at row 113: No module named 'rasterio'
# Error at row 114: No module named 'rasterio'
# Error at row 115: No module named 'rasterio'
# Error at row 116: No module named 'rasterio'
# Error at row 117: No module named 'rasterio'
# Error at row 118: No module named 'rasterio'
# Error at row 119: No module named 'rasterio'
# Error at row 120: No module named 'rasterio'
# Error at row 121: No module named 'rasterio'
# Error at row 122: No module named 'rasterio'
# Error at row 123: No module named 'rasterio'
# Error at row 124: No module named 'rasterio'
# Error at row 125: No module named 'rasterio'
# Error at row 126: No module named 'rasterio'
# Error at row 127: No module named 'rasterio'
# Error at row 128: No module named 'rasterio'
# Error at row 129: No module named 'rasterio'
# Error at row 130: No module named 'rasterio'
# Error at row 131: No module named 'rasterio'
# Error at row 132: No module named 'rasterio'
# Error at row 133: No module named 'rasterio'
# Error at row 134: No module named 'rasterio'
# Error at row 135: No module named 'rasterio'
# Error at row 136: No module named 'rasterio'
# Error at row 137: No module named 'rasterio'
# Error at row 138: No module named 'rasterio'
# Error at row 139: No module named 'rasterio'
# Error at row 140: No module named 'rasterio'
# Error at row 141: No module named 'rasterio'
# Error at row 142: No module named 'rasterio'
# Error at row 143: No module named 'rasterio'
# Error at row 144: No module named 'rasterio'
# Error at row 145: No module named 'rasterio'
# Error at row 146: No module named 'rasterio'
# Error at row 147: No module named 'rasterio'
# Error at row 148: No module named 'rasterio'
# Error at row 149: No module named 'rasterio'
# Error at row 150: No module named 'rasterio'
# Error at row 151: No module named 'rasterio'
# Error at row 152: No module named 'rasterio'
# Error at row 153: No module named 'rasterio'
# Error at row 154: No module named 'rasterio'
# Error at row 155: No module named 'rasterio'
# Error at row 156: No module named 'rasterio'
# Error at row 157: No module named 'rasterio'
# Error at row 158: No module named 'rasterio'
# Error at row 159: No module named 'rasterio'
# Error at row 160: No module named 'rasterio'
# Error at row 161: No module named 'rasterio'
# Error at row 162: No module named 'rasterio'
# Error at row 163: No module named 'rasterio'
# Error at row 164: No module named 'rasterio'
# Error at row 165: No module named 'rasterio'
# Error at row 166: No module named 'rasterio'
# Error at row 167: No module named 'rasterio'
# Error at row 168: No module named 'rasterio'
# Error at row 169: No module named 'rasterio'
# Error at row 170: No module named 'rasterio'
# Error at row 171: No module named 'rasterio'
# Error at row 172: No module named 'rasterio'
# Error at row 173: No module named 'rasterio'
# Error at row 174: No module named 'rasterio'
# Error at row 175: No module named 'rasterio'
# Error at row 176: No module named 'rasterio'
# Error at row 177: No module named 'rasterio'
# Error at row 178: No module named 'rasterio'
# Error at row 179: No module named 'rasterio'
# Error at row 180: No module named 'rasterio'
# Error at row 181: No module named 'rasterio'
# Error at row 182: No module named 'rasterio'
# Error at row 183: No module named 'rasterio'
# Error at row 184: No module named 'rasterio'
# Error at row 185: No module named 'rasterio'
# Error at row 186: No module named 'rasterio'
# Error at row 187: No module named 'rasterio'
# Error at row 188: No module named 'rasterio'
# Error at row 189: No module named 'rasterio'
# Error at row 190: No module named 'rasterio'
# Error at row 191: No module named 'rasterio'
# Error at row 192: No module named 'rasterio'
# Error at row 193: No module named 'rasterio'
# Error at row 194: No module named 'rasterio'
# Error at row 195: No module named 'rasterio'
# Error at row 196: No module named 'rasterio'
# Error at row 197: No module named 'rasterio'
# Error at row 198: No module named 'rasterio'
# Error at row 199: No module named 'rasterio'
# Error at row 200: No module named 'rasterio'
# Error at row 201: No module named 'rasterio'
# Error at row 202: No module named 'rasterio'
# Error at row 203: No module named 'rasterio'
# Error at row 204: No module named 'rasterio'
# Error at row 205: No module named 'rasterio'
# Error at row 206: No module named 'rasterio'
# Error at row 207: No module named 'rasterio'
# Error at row 208: No module named 'rasterio'
# Error at row 209: No module named 'rasterio'
# Error at row 210: No module named 'rasterio'
# Error at row 211: No module named 'rasterio'
# Error at row 212: No module named 'rasterio'
# Error at row 213: No module named 'rasterio'
# Error at row 214: No module named 'rasterio'
# Error at row 215: No module named 'rasterio'
# Error at row 216: No module named 'rasterio'
# Error at row 217: No module named 'rasterio'
# Error at row 218: No module named 'rasterio'
# Error at row 219: No module named 'rasterio'
# Error at row 220: No module named 'rasterio'
# Error at row 221: No module named 'rasterio'
# Error at row 222: No module named 'rasterio'
# Error at row 223: No module named 'rasterio'
# Error at row 224: No module named 'rasterio'
# Error at row 225: No module named 'rasterio'
# Error at row 226: No module named 'rasterio'
# Error at row 227: No module named 'rasterio'
# Error at row 228: No module named 'rasterio'
# Error at row 229: No module named 'rasterio'
# Error at row 230: No module named 'rasterio'
# Error at row 231: No module named 'rasterio'
# Error at row 232: No module named 'rasterio'
# Error at row 233: No module named 'rasterio'
# Error at row 234: No module named 'rasterio'
# Error at row 235: No module named 'rasterio'
# Error at row 236: No module named 'rasterio'
# Error at row 237: No module named 'rasterio'
# Error at row 238: No module named 'rasterio'
# Error at row 239: No module named 'rasterio'
# Error at row 240: No module named 'rasterio'
# Error at row 241: No module named 'rasterio'
# Error at row 242: No module named 'rasterio'
# Error at row 243: No module named 'rasterio'
# Error at row 244: No module named 'rasterio'
# Error at row 245: No module named 'rasterio'
# Error at row 246: No module named 'rasterio'
# Error at row 247: No module named 'rasterio'
# Error at row 248: No module named 'rasterio'
# Error at row 249: No module named 'rasterio'
# Error at row 250: No module named 'rasterio'
# Error at row 251: No module named 'rasterio'
# Error at row 252: No module named 'rasterio'
# Error at row 253: No module named 'rasterio'
# Error at row 254: No module named 'rasterio'
# Error at row 255: No module named 'rasterio'
# Error at row 256: No module named 'rasterio'
# Error at row 257: No module named 'rasterio'
# Error at row 258: No module named 'rasterio'
# Error at row 259: No module named 'rasterio'
# Error at row 260: No module named 'rasterio'
# Error at row 261: No module named 'rasterio'
# Error at row 262: No module named 'rasterio'
# Error at row 263: No module named 'rasterio'
# Error at row 264: No module named 'rasterio'
# Error at row 265: No module named 'rasterio'
# Error at row 266: No module named 'rasterio'
# Error at row 267: No module named 'rasterio'
# Error at row 268: No module named 'rasterio'
# Error at row 269: No module named 'rasterio'
# Error at row 270: No module named 'rasterio'
# Error at row 271: No module named 'rasterio'
# Error at row 272: No module named 'rasterio'
# Error at row 273: No module named 'rasterio'
# Error at row 274: No module named 'rasterio'
# Error at row 275: No module named 'rasterio'
# Error at row 276: No module named 'rasterio'
# Error at row 277: No module named 'rasterio'
# Error at row 278: No module named 'rasterio'
# Error at row 279: No module named 'rasterio'
# Error at row 280: No module named 'rasterio'
# Error at row 281: No module named 'rasterio'
# Error at row 282: No module named 'rasterio'
# Error at row 283: No module named 'rasterio'
# Error at row 284: No module named 'rasterio'
# Error at row 285: No module named 'rasterio'
# Error at row 286: No module named 'rasterio'
# Error at row 287: No module named 'rasterio'
# Error at row 288: No module named 'rasterio'
# Error at row 289: No module named 'rasterio'
# Error at row 290: No module named 'rasterio'
# Error at row 291: No module named 'rasterio'
# Error at row 292: No module named 'rasterio'
# Error at row 293: No module named 'rasterio'
# Error at row 294: No module named 'rasterio'
# Error at row 295: No module named 'rasterio'
# Error at row 296: No module named 'rasterio'
# Error at row 297: No module named 'rasterio'
# Error at row 298: No module named 'rasterio'
# Error at row 299: No module named 'rasterio'
# Error at row 300: No module named 'rasterio'
# Error at row 301: No module named 'rasterio'
# Error at row 302: No module named 'rasterio'
# Error at row 303: No module named 'rasterio'
# Error at row 304: No module named 'rasterio'
# Error at row 305: No module named 'rasterio'
# Error at row 306: No module named 'rasterio'
# Error at row 307: No module named 'rasterio'
# Error at row 308: No module named 'rasterio'
# Error at row 309: No module named 'rasterio'
# Error at row 310: No module named 'rasterio'
# Error at row 311: No module named 'rasterio'
# Error at row 312: No module named 'rasterio'
# Error at row 313: No module named 'rasterio'
# Error at row 314: No module named 'rasterio'
# Error at row 315: No module named 'rasterio'
# Error at row 316: No module named 'rasterio'
# Error at row 317: No module named 'rasterio'
# Error at row 318: No module named 'rasterio'
# Error at row 319: No module named 'rasterio'
# Error at row 320: No module named 'rasterio'
# Error at row 321: No module named 'rasterio'
# Error at row 322: No module named 'rasterio'
# Error at row 323: No module named 'rasterio'
# Error at row 324: No module named 'rasterio'
# Error at row 325: No module named 'rasterio'
# Error at row 326: No module named 'rasterio'
# Error at row 327: No module named 'rasterio'
# Error at row 328: No module named 'rasterio'
# Error at row 329: No module named 'rasterio'
# Error at row 330: No module named 'rasterio'
# Error at row 331: No module named 'rasterio'
# Error at row 332: No module named 'rasterio'
# Error at row 333: No module named 'rasterio'
# Error at row 334: No module named 'rasterio'
# Error at row 335: No module named 'rasterio'
# Error at row 336: No module named 'rasterio'
# Error at row 337: No module named 'rasterio'
# Error at row 338: No module named 'rasterio'
# Error at row 339: No module named 'rasterio'
# Error at row 340: No module named 'rasterio'
# Error at row 341: No module named 'rasterio'
# Error at row 342: No module named 'rasterio'
# Error at row 343: No module named 'rasterio'
# Error at row 344: No module named 'rasterio'
# Error at row 345: No module named 'rasterio'
# Error at row 346: No module named 'rasterio'
# Error at row 347: No module named 'rasterio'
# Error at row 348: No module named 'rasterio'
# Error at row 349: No module named 'rasterio'
# Error at row 350: No module named 'rasterio'
# Error at row 351: No module named 'rasterio'
# Error at row 352: No module named 'rasterio'
# Error at row 353: No module named 'rasterio'
# Error at row 354: No module named 'rasterio'
# Error at row 355: No module named 'rasterio'
# Error at row 356: No module named 'rasterio'
# Error at row 357: No module named 'rasterio'
# Error at row 358: No module named 'rasterio'
# Error at row 359: No module named 'rasterio'
# Error at row 360: No module named 'rasterio'
# Error at row 361: No module named 'rasterio'
# Error at row 362: No module named 'rasterio'
# Error at row 363: No module named 'rasterio'
# Error at row 364: No module named 'rasterio'
# Error at row 365: No module named 'rasterio'
# Error at row 366: No module named 'rasterio'
# Error at row 367: No module named 'rasterio'
# Error at row 368: No module named 'rasterio'
# Error at row 369: No module named 'rasterio'
# Error at row 370: No module named 'rasterio'
# Error at row 371: No module named 'rasterio'
# Error at row 372: No module named 'rasterio'
# Error at row 373: No module named 'rasterio'
# Error at row 374: No module named 'rasterio'
# Error at row 375: No module named 'rasterio'
# Error at row 376: No module named 'rasterio'
# Error at row 377: No module named 'rasterio'
# Error at row 378: No module named 'rasterio'
# Error at row 379: No module named 'rasterio'
# Error at row 380: No module named 'rasterio'
# Error at row 381: No module named 'rasterio'
# Error at row 382: No module named 'rasterio'
# Error at row 383: No module named 'rasterio'
# Error at row 384: No module named 'rasterio'
# Error at row 385: No module named 'rasterio'
# Error at row 386: No module named 'rasterio'
# Error at row 387: No module named 'rasterio'
# Error at row 388: No module named 'rasterio'
# Error at row 389: No module named 'rasterio'
# Error at row 390: No module named 'rasterio'
# Error at row 391: No module named 'rasterio'
# Error at row 392: No module named 'rasterio'
# Error at row 393: No module named 'rasterio'
# Error at row 394: No module named 'rasterio'
# Error at row 395: No module named 'rasterio'
# Error at row 396: No module named 'rasterio'
# Error at row 397: No module named 'rasterio'
# Error at row 398: No module named 'rasterio'
# Error at row 399: No module named 'rasterio'
# Error at row 400: No module named 'rasterio'
# Error at row 401: No module named 'rasterio'
# Error at row 402: No module named 'rasterio'
# Error at row 403: No module named 'rasterio'
# Error at row 404: No module named 'rasterio'
# Error at row 405: No module named 'rasterio'
# Error at row 406: No module named 'rasterio'
# Error at row 407: No module named 'rasterio'
# Error at row 408: No module named 'rasterio'
# Error at row 409: No module named 'rasterio'
# Error at row 410: No module named 'rasterio'
# Error at row 411: No module named 'rasterio'
# Error at row 412: No module named 'rasterio'
# Error at row 413: No module named 'rasterio'
# Error at row 414: No module named 'rasterio'
# Error at row 415: No module named 'rasterio'
# Error at row 416: No module named 'rasterio'
# Error at row 417: No module named 'rasterio'
# Error at row 418: No module named 'rasterio'
# Error at row 419: No module named 'rasterio'
# Error at row 420: No module named 'rasterio'
# Error at row 421: No module named 'rasterio'
# Error at row 422: No module named 'rasterio'
# Error at row 423: No module named 'rasterio'
# Error at row 424: No module named 'rasterio'
# Error at row 425: No module named 'rasterio'
# Error at row 426: No module named 'rasterio'
# Error at row 427: No module named 'rasterio'
# Error at row 428: No module named 'rasterio'
# Error at row 429: No module named 'rasterio'
# Error at row 430: No module named 'rasterio'
# Error at row 431: No module named 'rasterio'
# Error at row 432: No module named 'rasterio'
# Error at row 433: No module named 'rasterio'
# Error at row 434: No module named 'rasterio'
# Error at row 435: No module named 'rasterio'
# Error at row 436: No module named 'rasterio'
# Error at row 437: No module named 'rasterio'
# Error at row 438: No module named 'rasterio'
# Error at row 439: No module named 'rasterio'
# Error at row 440: No module named 'rasterio'
# Error at row 441: No module named 'rasterio'
# Error at row 442: No module named 'rasterio'
# Error at row 443: No module named 'rasterio'
# Error at row 444: No module named 'rasterio'
# Error at row 445: No module named 'rasterio'
# Error at row 446: No module named 'rasterio'
# Error at row 447: No module named 'rasterio'
# Error at row 448: No module named 'rasterio'
# Error at row 449: No module named 'rasterio'
# Error at row 450: No module named 'rasterio'
# Error at row 451: No module named 'rasterio'
# Error at row 452: No module named 'rasterio'
# Error at row 453: No module named 'rasterio'
# Error at row 454: No module named 'rasterio'
# Error at row 455: No module named 'rasterio'
# Error at row 456: No module named 'rasterio'
# Error at row 457: No module named 'rasterio'
# Error at row 458: No module named 'rasterio'
# Error at row 459: No module named 'rasterio'
# Error at row 460: No module named 'rasterio'
# Error at row 461: No module named 'rasterio'
# Error at row 462: No module named 'rasterio'
# Error at row 463: No module named 'rasterio'
# Error at row 464: No module named 'rasterio'
# Error at row 465: No module named 'rasterio'
# Error at row 466: No module named 'rasterio'
# Error at row 467: No module named 'rasterio'
# Error at row 468: No module named 'rasterio'
# Error at row 469: No module named 'rasterio'
# Error at row 470: No module named 'rasterio'
# Error at row 471: No module named 'rasterio'
# Error at row 472: No module named 'rasterio'
# Error at row 473: No module named 'rasterio'
# Error at row 474: No module named 'rasterio'
# Error at row 475: No module named 'rasterio'
# Error at row 476: No module named 'rasterio'
# Error at row 477: No module named 'rasterio'
# Error at row 478: No module named 'rasterio'
# Error at row 479: No module named 'rasterio'
# Error at row 480: No module named 'rasterio'
# Error at row 481: No module named 'rasterio'
# Error at row 482: No module named 'rasterio'
# Error at row 483: No module named 'rasterio'
# Error at row 484: No module named 'rasterio'
# Error at row 485: No module named 'rasterio'
# Error at row 486: No module named 'rasterio'
# Error at row 487: No module named 'rasterio'
# Error at row 488: No module named 'rasterio'
# Error at row 489: No module named 'rasterio'
# Error at row 490: No module named 'rasterio'
# Error at row 491: No module named 'rasterio'
# Error at row 492: No module named 'rasterio'
# Error at row 493: No module named 'rasterio'
# Error at row 494: No module named 'rasterio'
# Error at row 495: No module named 'rasterio'
# Error at row 496: No module named 'rasterio'
# Error at row 497: No module named 'rasterio'
# Error at row 498: No module named 'rasterio'
# Error at row 499: No module named 'rasterio'
# Error at row 500: No module named 'rasterio'
# Error at row 501: No module named 'rasterio'
# Error at row 502: No module named 'rasterio'
# Error at row 503: No module named 'rasterio'
# Error at row 504: No module named 'rasterio'
# Error at row 505: No module named 'rasterio'
# Error at row 506: No module named 'rasterio'
# Error at row 507: No module named 'rasterio'
# Error at row 508: No module named 'rasterio'
# Error at row 509: No module named 'rasterio'
# Error at row 510: No module named 'rasterio'
# Error at row 511: No module named 'rasterio'
# Error at row 512: No module named 'rasterio'
# Error at row 513: No module named 'rasterio'
# Error at row 514: No module named 'rasterio'
# Error at row 515: No module named 'rasterio'
# Error at row 516: No module named 'rasterio'
# Error at row 517: No module named 'rasterio'
# Error at row 518: No module named 'rasterio'
# Error at row 519: No module named 'rasterio'
# Error at row 520: No module named 'rasterio'
# Error at row 521: No module named 'rasterio'
# Error at row 522: No module named 'rasterio'
# Error at row 523: No module named 'rasterio'
# Error at row 524: No module named 'rasterio'
# Error at row 525: No module named 'rasterio'
# Error at row 526: No module named 'rasterio'
# Error at row 527: No module named 'rasterio'
# Error at row 528: No module named 'rasterio'
# Error at row 529: No module named 'rasterio'
# Error at row 530: No module named 'rasterio'
# Error at row 531: No module named 'rasterio'
# Error at row 532: No module named 'rasterio'
# Error at row 533: No module named 'rasterio'
# Error at row 534: No module named 'rasterio'
# Error at row 535: No module named 'rasterio'
# Error at row 536: No module named 'rasterio'
# Error at row 537: No module named 'rasterio'
# Error at row 538: No module named 'rasterio'
# Error at row 539: No module named 'rasterio'
# Error at row 540: No module named 'rasterio'
# Error at row 541: No module named 'rasterio'
# Error at row 542: No module named 'rasterio'
# Error at row 543: No module named 'rasterio'
# Error at row 544: No module named 'rasterio'
# Error at row 545: No module named 'rasterio'
# Error at row 546: No module named 'rasterio'
# Error at row 547: No module named 'rasterio'
# Error at row 548: No module named 'rasterio'
# Error at row 549: No module named 'rasterio'
# Error at row 550: No module named 'rasterio'
# Error at row 551: No module named 'rasterio'
# Error at row 552: No module named 'rasterio'
# Error at row 553: No module named 'rasterio'
# Error at row 554: No module named 'rasterio'
# Error at row 555: No module named 'rasterio'
# Error at row 556: No module named 'rasterio'
# Error at row 557: No module named 'rasterio'
# Error at row 558: No module named 'rasterio'
# Error at row 559: No module named 'rasterio'
# Error at row 560: No module named 'rasterio'
# Error at row 561: No module named 'rasterio'
# Error at row 562: No module named 'rasterio'
# Error at row 563: No module named 'rasterio'
# Error at row 564: No module named 'rasterio'
# Error at row 565: No module named 'rasterio'
# Error at row 566: No module named 'rasterio'
# Error at row 567: No module named 'rasterio'
# Error at row 568: No module named 'rasterio'
# Error at row 569: No module named 'rasterio'
# Error at row 570: No module named 'rasterio'
# Error at row 571: No module named 'rasterio'
# Error at row 572: No module named 'rasterio'
# Error at row 573: No module named 'rasterio'
# Error at row 574: No module named 'rasterio'
# Error at row 575: No module named 'rasterio'
# Error at row 576: No module named 'rasterio'
# Error at row 577: No module named 'rasterio'
# Error at row 578: No module named 'rasterio'
# Error at row 579: No module named 'rasterio'
# Error at row 580: No module named 'rasterio'
# Error at row 581: No module named 'rasterio'
# Error at row 582: No module named 'rasterio'
# Error at row 583: No module named 'rasterio'
# Error at row 584: No module named 'rasterio'
# Error at row 585: No module named 'rasterio'
# Error at row 586: No module named 'rasterio'
# Error at row 587: No module named 'rasterio'
# Error at row 588: No module named 'rasterio'
# Error at row 589: No module named 'rasterio'
# Error at row 590: No module named 'rasterio'
# Error at row 591: No module named 'rasterio'
# Error at row 592: No module named 'rasterio'
# Error at row 593: No module named 'rasterio'
# Error at row 594: No module named 'rasterio'
# Error at row 595: No module named 'rasterio'
# Error at row 596: No module named 'rasterio'
# Error at row 597: No module named 'rasterio'
# Error at row 598: No module named 'rasterio'
# Error at row 599: No module named 'rasterio'
# Error at row 600: No module named 'rasterio'
# Error at row 601: No module named 'rasterio'
# Error at row 602: No module named 'rasterio'
# Error at row 603: No module named 'rasterio'
# Error at row 604: No module named 'rasterio'
# Error at row 605: No module named 'rasterio'
# Error at row 606: No module named 'rasterio'
# Error at row 607: No module named 'rasterio'
# Error at row 608: No module named 'rasterio'
# Error at row 609: No module named 'rasterio'
# Error at row 610: No module named 'rasterio'
# Error at row 611: No module named 'rasterio'
# Error at row 612: No module named 'rasterio'
# Error at row 613: No module named 'rasterio'
# Error at row 614: No module named 'rasterio'
# Error at row 615: No module named 'rasterio'
# Error at row 616: No module named 'rasterio'
# Error at row 617: No module named 'rasterio'
# Error at row 618: No module named 'rasterio'
# Error at row 619: No module named 'rasterio'
# Error at row 620: No module named 'rasterio'
# Error at row 621: No module named 'rasterio'
# Error at row 622: No module named 'rasterio'
# Error at row 623: No module named 'rasterio'
# Error at row 624: No module named 'rasterio'
# Error at row 625: No module named 'rasterio'
# Error at row 626: No module named 'rasterio'
# Error at row 627: No module named 'rasterio'
# Error at row 628: No module named 'rasterio'
# Error at row 629: No module named 'rasterio'
# Error at row 630: No module named 'rasterio'
# Error at row 631: No module named 'rasterio'
# Error at row 632: No module named 'rasterio'
# Error at row 633: No module named 'rasterio'
# Error at row 634: No module named 'rasterio'
# Error at row 635: No module named 'rasterio'
# Error at row 636: No module named 'rasterio'
# Error at row 637: No module named 'rasterio'
# Error at row 638: No module named 'rasterio'
# Error at row 639: No module named 'rasterio'
# Error at row 640: No module named 'rasterio'
# Error at row 641: No module named 'rasterio'
# Error at row 642: No module named 'rasterio'
# Error at row 643: No module named 'rasterio'
# Error at row 644: No module named 'rasterio'
# Error at row 645: No module named 'rasterio'
# Error at row 646: No module named 'rasterio'
# Error at row 647: No module named 'rasterio'
# Error at row 648: No module named 'rasterio'
# Error at row 649: No module named 'rasterio'
# Error at row 650: No module named 'rasterio'
# Error at row 651: No module named 'rasterio'
# Error at row 652: No module named 'rasterio'
# Error at row 653: No module named 'rasterio'
# Error at row 654: No module named 'rasterio'
# Error at row 655: No module named 'rasterio'
# Error at row 656: No module named 'rasterio'
# Error at row 657: No module named 'rasterio'
# Error at row 658: No module named 'rasterio'
# Error at row 659: No module named 'rasterio'
# Error at row 660: No module named 'rasterio'
# Error at row 661: No module named 'rasterio'
# Error at row 662: No module named 'rasterio'
# Error at row 663: No module named 'rasterio'
# Error at row 664: No module named 'rasterio'
# Error at row 665: No module named 'rasterio'
# Error at row 666: No module named 'rasterio'
# Error at row 667: No module named 'rasterio'
# Error at row 668: No module named 'rasterio'
# Error at row 669: No module named 'rasterio'
# Error at row 670: No module named 'rasterio'
# Error at row 671: No module named 'rasterio'
# Error at row 672: No module named 'rasterio'
# Error at row 673: No module named 'rasterio'
# Error at row 674: No module named 'rasterio'
# Error at row 675: No module named 'rasterio'
# Error at row 676: No module named 'rasterio'
# Error at row 677: No module named 'rasterio'
# Error at row 678: No module named 'rasterio'
# Error at row 679: No module named 'rasterio'
# Error at row 680: No module named 'rasterio'
# Error at row 681: No module named 'rasterio'
# Error at row 682: No module named 'rasterio'
# Error at row 683: No module named 'rasterio'
# Error at row 684: No module named 'rasterio'
# Error at row 685: No module named 'rasterio'
# Error at row 686: No module named 'rasterio'
# Error at row 687: No module named 'rasterio'
# Error at row 688: No module named 'rasterio'
# Error at row 689: No module named 'rasterio'
# Error at row 690: No module named 'rasterio'
# Error at row 691: No module named 'rasterio'
# Error at row 692: No module named 'rasterio'
# Error at row 693: No module named 'rasterio'
# Error at row 694: No module named 'rasterio'
# Error at row 695: No module named 'rasterio'
# Error at row 696: No module named 'rasterio'
# Error at row 697: No module named 'rasterio'
# Error at row 698: No module named 'rasterio'
# Error at row 699: No module named 'rasterio'
# Error at row 700: No module named 'rasterio'
# Error at row 701: No module named 'rasterio'
# Error at row 702: No module named 'rasterio'
# Error at row 703: No module named 'rasterio'
# Error at row 704: No module named 'rasterio'
# Error at row 705: No module named 'rasterio'
# Error at row 706: No module named 'rasterio'
# Error at row 707: No module named 'rasterio'
# Error at row 708: No module named 'rasterio'
# Error at row 709: No module named 'rasterio'
# Error at row 710: No module named 'rasterio'
# Error at row 711: No module named 'rasterio'
# Error at row 712: No module named 'rasterio'
# Error at row 713: No module named 'rasterio'
# Error at row 714: No module named 'rasterio'
# Error at row 715: No module named 'rasterio'
# Error at row 716: No module named 'rasterio'
# Error at row 717: No module named 'rasterio'
# Error at row 718: No module named 'rasterio'
# Error at row 719: No module named 'rasterio'
# Error at row 720: No module named 'rasterio'
# Error at row 721: No module named 'rasterio'
# Error at row 722: No module named 'rasterio'
# Error at row 723: No module named 'rasterio'
# Error at row 724: No module named 'rasterio'
# Error at row 725: No module named 'rasterio'
# Error at row 726: No module named 'rasterio'
# Error at row 727: No module named 'rasterio'
# Error at row 728: No module named 'rasterio'
# Error at row 729: No module named 'rasterio'
# Error at row 730: No module named 'rasterio'
# Error at row 731: No module named 'rasterio'
# Error at row 732: No module named 'rasterio'
# Error at row 733: No module named 'rasterio'
# Error at row 734: No module named 'rasterio'
# Error at row 735: No module named 'rasterio'
# Error at row 736: No module named 'rasterio'
# Error at row 737: No module named 'rasterio'
# Error at row 738: No module named 'rasterio'
# Error at row 739: No module named 'rasterio'
# Error at row 740: No module named 'rasterio'
# Error at row 741: No module named 'rasterio'
# Error at row 742: No module named 'rasterio'
# Error at row 743: No module named 'rasterio'
# Error at row 744: No module named 'rasterio'
# Error at row 745: No module named 'rasterio'
# Error at row 746: No module named 'rasterio'
# Error at row 747: No module named 'rasterio'
# Error at row 748: No module named 'rasterio'
# Error at row 749: No module named 'rasterio'
# Error at row 750: No module named 'rasterio'
# Error at row 751: No module named 'rasterio'
# Error at row 752: No module named 'rasterio'
# Error at row 753: No module named 'rasterio'
# Error at row 754: No module named 'rasterio'
# Error at row 755: No module named 'rasterio'
# Error at row 756: No module named 'rasterio'
# Error at row 757: No module named 'rasterio'
# Error at row 758: No module named 'rasterio'
# Error at row 759: No module named 'rasterio'
# Error at row 760: No module named 'rasterio'
# Error at row 761: No module named 'rasterio'
# Error at row 762: No module named 'rasterio'
# Error at row 763: No module named 'rasterio'
# Error at row 764: No module named 'rasterio'
# Error at row 765: No module named 'rasterio'
# Error at row 766: No module named 'rasterio'
# Error at row 767: No module named 'rasterio'
# Error at row 768: No module named 'rasterio'
# Error at row 769: No module named 'rasterio'
# Error at row 770: No module named 'rasterio'
# Error at row 771: No module named 'rasterio'
# Error at row 772: No module named 'rasterio'
# Error at row 773: No module named 'rasterio'
# Error at row 774: No module named 'rasterio'
# Error at row 775: No module named 'rasterio'
# Error at row 776: No module named 'rasterio'
# Error at row 777: No module named 'rasterio'
# Error at row 778: No module named 'rasterio'
# Error at row 779: No module named 'rasterio'
# Error at row 780: No module named 'rasterio'
# Error at row 781: No module named 'rasterio'
# Error at row 782: No module named 'rasterio'
# Error at row 783: No module named 'rasterio'
# Error at row 784: No module named 'rasterio'
# Error at row 785: No module named 'rasterio'
# Error at row 786: No module named 'rasterio'
# Error at row 787: No module named 'rasterio'
# Error at row 788: No module named 'rasterio'
# Error at row 789: No module named 'rasterio'
# Error at row 790: No module named 'rasterio'
# Error at row 791: No module named 'rasterio'
# Error at row 792: No module named 'rasterio'
# Error at row 793: No module named 'rasterio'
# Error at row 794: No module named 'rasterio'
# Error at row 795: No module named 'rasterio'
# Error at row 796: No module named 'rasterio'
# Error at row 797: No module named 'rasterio'
# Error at row 798: No module named 'rasterio'
# Error at row 799: No module named 'rasterio'
# Error at row 800: No module named 'rasterio'
# Error at row 801: No module named 'rasterio'
# Error at row 802: No module named 'rasterio'
# Error at row 803: No module named 'rasterio'
# Error at row 804: No module named 'rasterio'
# Error at row 805: No module named 'rasterio'
# Error at row 806: No module named 'rasterio'
# Error at row 807: No module named 'rasterio'
# Error at row 808: No module named 'rasterio'
# Error at row 809: No module named 'rasterio'
# Error at row 810: No module named 'rasterio'
# Error at row 811: No module named 'rasterio'
# Error at row 812: No module named 'rasterio'
# Error at row 813: No module named 'rasterio'
# Error at row 814: No module named 'rasterio'
# Error at row 815: No module named 'rasterio'
# Error at row 816: No module named 'rasterio'
# Error at row 817: No module named 'rasterio'
# Error at row 818: No module named 'rasterio'
# Error at row 819: No module named 'rasterio'
# Error at row 820: No module named 'rasterio'
# Error at row 821: No module named 'rasterio'
# Error at row 822: No module named 'rasterio'
# Error at row 823: No module named 'rasterio'
# Error at row 824: No module named 'rasterio'
# Error at row 825: No module named 'rasterio'
# Error at row 826: No module named 'rasterio'
# Error at row 827: No module named 'rasterio'
# Error at row 828: No module named 'rasterio'
# Error at row 829: No module named 'rasterio'
# Error at row 830: No module named 'rasterio'
# Error at row 831: No module named 'rasterio'
# Error at row 832: No module named 'rasterio'
# Error at row 833: No module named 'rasterio'
# Error at row 834: No module named 'rasterio'
# Error at row 835: No module named 'rasterio'
# Error at row 836: No module named 'rasterio'
# Error at row 837: No module named 'rasterio'
# Error at row 838: No module named 'rasterio'
# Error at row 839: No module named 'rasterio'
# Error at row 840: No module named 'rasterio'
# Error at row 841: No module named 'rasterio'
# Error at row 842: No module named 'rasterio'
# Error at row 843: No module named 'rasterio'
# Error at row 844: No module named 'rasterio'
# Error at row 845: No module named 'rasterio'
# Error at row 846: No module named 'rasterio'
# Error at row 847: No module named 'rasterio'
# Error at row 848: No module named 'rasterio'
# Error at row 849: No module named 'rasterio'
# Error at row 850: No module named 'rasterio'
# Error at row 851: No module named 'rasterio'
# Error at row 852: No module named 'rasterio'
# Error at row 853: No module named 'rasterio'
# Error at row 854: No module named 'rasterio'
# Error at row 855: No module named 'rasterio'
# Error at row 856: No module named 'rasterio'
# Error at row 857: No module named 'rasterio'
# Error at row 858: No module named 'rasterio'
# Error at row 859: No module named 'rasterio'
# Error at row 860: No module named 'rasterio'
# Error at row 861: No module named 'rasterio'
# Error at row 862: No module named 'rasterio'
# Error at row 863: No module named 'rasterio'
# Error at row 864: No module named 'rasterio'
# Error at row 865: No module named 'rasterio'
# Error at row 866: No module named 'rasterio'
# Error at row 867: No module named 'rasterio'
# Error at row 868: No module named 'rasterio'
# Error at row 869: No module named 'rasterio'
# Error at row 870: No module named 'rasterio'
# Error at row 871: No module named 'rasterio'
# Error at row 872: No module named 'rasterio'
# Error at row 873: No module named 'rasterio'
# Error at row 874: No module named 'rasterio'
# Error at row 875: No module named 'rasterio'
# Error at row 876: No module named 'rasterio'
# Error at row 877: No module named 'rasterio'
# Error at row 878: No module named 'rasterio'
# Error at row 879: No module named 'rasterio'
# Error at row 880: No module named 'rasterio'
# Error at row 881: No module named 'rasterio'
# Error at row 882: No module named 'rasterio'
# Error at row 883: No module named 'rasterio'
# Error at row 884: No module named 'rasterio'
# Error at row 885: No module named 'rasterio'
# Error at row 886: No module named 'rasterio'
# Error at row 887: No module named 'rasterio'
# Error at row 888: No module named 'rasterio'
# Error at row 889: No module named 'rasterio'
# Error at row 890: No module named 'rasterio'
# Error at row 891: No module named 'rasterio'
# Error at row 892: No module named 'rasterio'
# Error at row 893: No module named 'rasterio'
# Error at row 894: No module named 'rasterio'
# Error at row 895: No module named 'rasterio'
# Error at row 896: No module named 'rasterio'
# Error at row 897: No module named 'rasterio'
# Error at row 898: No module named 'rasterio'
# Error at row 899: No module named 'rasterio'
# Error at row 900: No module named 'rasterio'
# Error at row 901: No module named 'rasterio'
# Error at row 902: No module named 'rasterio'
# Error at row 903: No module named 'rasterio'
# Error at row 904: No module named 'rasterio'
# Error at row 905: No module named 'rasterio'
# Error at row 906: No module named 'rasterio'
# Error at row 907: No module named 'rasterio'
# Error at row 908: No module named 'rasterio'
# Error at row 909: No module named 'rasterio'
# Error at row 910: No module named 'rasterio'
# Error at row 911: No module named 'rasterio'
# Error at row 912: No module named 'rasterio'
# Error at row 913: No module named 'rasterio'
# Error at row 914: No module named 'rasterio'
# Error at row 915: No module named 'rasterio'
# Error at row 916: No module named 'rasterio'
# Error at row 917: No module named 'rasterio'
# Error at row 918: No module named 'rasterio'
# Error at row 919: No module named 'rasterio'
# Error at row 920: No module named 'rasterio'
# Error at row 921: No module named 'rasterio'
# Error at row 922: No module named 'rasterio'
# Error at row 923: No module named 'rasterio'
# Error at row 924: No module named 'rasterio'
# Error at row 925: No module named 'rasterio'
# Error at row 926: No module named 'rasterio'
# Error at row 927: No module named 'rasterio'
# Error at row 928: No module named 'rasterio'
# Error at row 929: No module named 'rasterio'
# Error at row 930: No module named 'rasterio'
# Error at row 931: No module named 'rasterio'
# Error at row 932: No module named 'rasterio'
# Error at row 933: No module named 'rasterio'
# Error at row 934: No module named 'rasterio'
# Error at row 935: No module named 'rasterio'
# Error at row 936: No module named 'rasterio'
# Error at row 937: No module named 'rasterio'
# Error at row 938: No module named 'rasterio'
# Error at row 939: No module named 'rasterio'
# Error at row 940: No module named 'rasterio'
# Error at row 941: No module named 'rasterio'
# Error at row 942: No module named 'rasterio'
# Error at row 943: No module named 'rasterio'
# Error at row 944: No module named 'rasterio'
# Error at row 945: No module named 'rasterio'
# Error at row 946: No module named 'rasterio'
# Error at row 947: No module named 'rasterio'
# Error at row 948: No module named 'rasterio'
# Error at row 949: No module named 'rasterio'
# Error at row 950: No module named 'rasterio'
# Error at row 951: No module named 'rasterio'
# Error at row 952: No module named 'rasterio'
# Error at row 953: No module named 'rasterio'
# Error at row 954: No module named 'rasterio'
# Error at row 955: No module named 'rasterio'
# Error at row 956: No module named 'rasterio'
# Error at row 957: No module named 'rasterio'
# Error at row 958: No module named 'rasterio'
# Error at row 959: No module named 'rasterio'
# Error at row 960: No module named 'rasterio'
# Error at row 961: No module named 'rasterio'
# Error at row 962: No module named 'rasterio'
# Error at row 963: No module named 'rasterio'
# Error at row 964: No module named 'rasterio'
# Error at row 965: No module named 'rasterio'
# Error at row 966: No module named 'rasterio'
# Error at row 967: No module named 'rasterio'
# Error at row 968: No module named 'rasterio'
# Error at row 969: No module named 'rasterio'
# Error at row 970: No module named 'rasterio'
# Error at row 971: No module named 'rasterio'
# Error at row 972: No module named 'rasterio'
# Error at row 973: No module named 'rasterio'
# Error at row 974: No module named 'rasterio'
# Error at row 975: No module named 'rasterio'
# Error at row 976: No module named 'rasterio'
# Error at row 977: No module named 'rasterio'
# Error at row 978: No module named 'rasterio'
# Error at row 979: No module named 'rasterio'
# Error at row 980: No module named 'rasterio'
# Error at row 981: No module named 'rasterio'
# Error at row 982: No module named 'rasterio'
# Error at row 983: No module named 'rasterio'
# Error at row 984: No module named 'rasterio'
# Error at row 985: No module named 'rasterio'
# Error at row 986: No module named 'rasterio'
# Error at row 987: No module named 'rasterio'
# Error at row 988: No module named 'rasterio'
# Error at row 989: No module named 'rasterio'
# Error at row 990: No module named 'rasterio'
# Error at row 991: No module named 'rasterio'
# Error at row 992: No module named 'rasterio'
# Error at row 993: No module named 'rasterio'
# Error at row 994: No module named 'rasterio'
# Error at row 995: No module named 'rasterio'
# Error at row 996: No module named 'rasterio'
# Error at row 997: No module named 'rasterio'
# Error at row 998: No module named 'rasterio'
# Error at row 999: No module named 'rasterio'
# Error at row 1000: No module named 'rasterio'
# Error at row 1001: No module named 'rasterio'
# Error at row 1002: No module named 'rasterio'
# Error at row 1003: No module named 'rasterio'
# Error at row 1004: No module named 'rasterio'
# Error at row 1005: No module named 'rasterio'
# Error at row 1006: No module named 'rasterio'
# Error at row 1007: No module named 'rasterio'
# Error at row 1008: No module named 'rasterio'
# Error at row 1009: No module named 'rasterio'
# Error at row 1010: No module named 'rasterio'
# Error at row 1011: No module named 'rasterio'
# Error at row 1012: No module named 'rasterio'
# Error at row 1013: No module named 'rasterio'
# Error at row 1014: No module named 'rasterio'
# Error at row 1015: No module named 'rasterio'
# Error at row 1016: No module named 'rasterio'
# Error at row 1017: No module named 'rasterio'
# Error at row 1018: No module named 'rasterio'
# Error at row 1019: No module named 'rasterio'
# Error at row 1020: No module named 'rasterio'
# Error at row 1021: No module named 'rasterio'
# Error at row 1022: No module named 'rasterio'
# Error at row 1023: No module named 'rasterio'
# Error at row 1024: No module named 'rasterio'
# Error at row 1025: No module named 'rasterio'
# Error at row 1026: No module named 'rasterio'
# Error at row 1027: No module named 'rasterio'
# Error at row 1028: No module named 'rasterio'
# Error at row 1029: No module named 'rasterio'
# Error at row 1030: No module named 'rasterio'
# Error at row 1031: No module named 'rasterio'
# Error at row 1032: No module named 'rasterio'
# Error at row 1033: No module named 'rasterio'
# Error at row 1034: No module named 'rasterio'
# Error at row 1035: No module named 'rasterio'
# Error at row 1036: No module named 'rasterio'
# Error at row 1037: No module named 'rasterio'
# Error at row 1038: No module named 'rasterio'
# Error at row 1039: No module named 'rasterio'
# Error at row 1040: No module named 'rasterio'
# Error at row 1041: No module named 'rasterio'
# Error at row 1042: No module named 'rasterio'
# Error at row 1043: No module named 'rasterio'
# Error at row 1044: No module named 'rasterio'
# Error at row 1045: No module named 'rasterio'
# Error at row 1046: No module named 'rasterio'
# Error at row 1047: No module named 'rasterio'
# Error at row 1048: No module named 'rasterio'
# Error at row 1049: No module named 'rasterio'
# Error at row 1050: No module named 'rasterio'
# Error at row 1051: No module named 'rasterio'
# Error at row 1052: No module named 'rasterio'
# Error at row 1053: No module named 'rasterio'
# Error at row 1054: No module named 'rasterio'
# Error at row 1055: No module named 'rasterio'
# Error at row 1056: No module named 'rasterio'
# Error at row 1057: No module named 'rasterio'
# Error at row 1058: No module named 'rasterio'
# Error at row 1059: No module named 'rasterio'
# Error at row 1060: No module named 'rasterio'
# Error at row 1061: No module named 'rasterio'
# Error at row 1062: No module named 'rasterio'
# Error at row 1063: No module named 'rasterio'
# Error at row 1064: No module named 'rasterio'
# Error at row 1065: No module named 'rasterio'
# Error at row 1066: No module named 'rasterio'
# ...
# Error at row 1974: No module named 'rasterio'
# Error at row 1975: No module named 'rasterio'
# Error at row 1976: No module named 'rasterio'
# Error at row 1977: No module named 'rasterio'
# Error at row 1978: No module named 'rasterio'
# Error at row 1979: No module named 'rasterio'
# Error at row 1980: No module named 'rasterio'
# Error at row 1981: No module named 'rasterio'
# Error at row 1982: No module named 'rasterio'
# Error at row 1983: No module named 'rasterio'
# Error at row 1984: No module named 'rasterio'
# Error at row 1985: No module named 'rasterio'
# Error at row 1986: No module named 'rasterio'
# Error at row 1987: No module named 'rasterio'
# Error at row 1988: No module named 'rasterio'
# Error at row 1989: No module named 'rasterio'
# Error at row 1990: No module named 'rasterio'
# Error at row 1991: No module named 'rasterio'
# Error at row 1992: No module named 'rasterio'
# Error at row 1993: No module named 'rasterio'
# Error at row 1994: No module named 'rasterio'
# Error at row 1995: No module named 'rasterio'
# Error at row 1996: No module named 'rasterio'
# Error at row 1997: No module named 'rasterio'
# Error at row 1998: No module named 'rasterio'
# Error at row 1999: No module named 'rasterio'
# Error at row 2000: No module named 'rasterio'
# Error at row 2001: No module named 'rasterio'
# Error at row 2002: No module named 'rasterio'
# Error at row 2003: No module named 'rasterio'
# Error at row 2004: No module named 'rasterio'
# Error at row 2005: No module named 'rasterio'
# Error at row 2006: No module named 'rasterio'
# Error at row 2007: No module named 'rasterio'
# Error at row 2008: No module named 'rasterio'
# Error at row 2009: No module named 'rasterio'
# Error at row 2010: No module named 'rasterio'
# Error at row 2011: No module named 'rasterio'
# Error at row 2012: No module named 'rasterio'
# Error at row 2013: No module named 'rasterio'
# Error at row 2014: No module named 'rasterio'
# Error at row 2015: No module named 'rasterio'
# Error at row 2016: No module named 'rasterio'
# Error at row 2017: No module named 'rasterio'
# Error at row 2018: No module named 'rasterio'
# Error at row 2019: No module named 'rasterio'
# Error at row 2020: No module named 'rasterio'
# Error at row 2021: No module named 'rasterio'
# Error at row 2022: No module named 'rasterio'
# Error at row 2023: No module named 'rasterio'
# Error at row 2024: No module named 'rasterio'
# Error at row 2025: No module named 'rasterio'
# Error at row 2026: No module named 'rasterio'
# Error at row 2027: No module named 'rasterio'
# Error at row 2028: No module named 'rasterio'
# Error at row 2029: No module named 'rasterio'
# Error at row 2030: No module named 'rasterio'
# Error at row 2031: No module named 'rasterio'
# Error at row 2032: No module named 'rasterio'
# Error at row 2033: No module named 'rasterio'
# Error at row 2034: No module named 'rasterio'
# Error at row 2035: No module named 'rasterio'
# Error at row 2036: No module named 'rasterio'
# Error at row 2037: No module named 'rasterio'
# Error at row 2038: No module named 'rasterio'
# Error at row 2039: No module named 'rasterio'
# Error at row 2040: No module named 'rasterio'
# Error at row 2041: No module named 'rasterio'
# Error at row 2042: No module named 'rasterio'
# Error at row 2043: No module named 'rasterio'
# Error at row 2044: No module named 'rasterio'
# Error at row 2045: No module named 'rasterio'
# Error at row 2046: No module named 'rasterio'
# Error at row 2047: No module named 'rasterio'
# Error at row 2048: No module named 'rasterio'
# Error at row 2049: No module named 'rasterio'
# Error at row 2050: No module named 'rasterio'
# Error at row 2051: No module named 'rasterio'
# Error at row 2052: No module named 'rasterio'
# Error at row 2053: No module named 'rasterio'
# Error at row 2054: No module named 'rasterio'
# Error at row 2055: No module named 'rasterio'
# Error at row 2056: No module named 'rasterio'
# Error at row 2057: No module named 'rasterio'
# Error at row 2058: No module named 'rasterio'
# Error at row 2059: No module named 'rasterio'
# Error at row 2060: No module named 'rasterio'
# Error at row 2061: No module named 'rasterio'
# Error at row 2062: No module named 'rasterio'
# Error at row 2063: No module named 'rasterio'
# Error at row 2064: No module named 'rasterio'
# Error at row 2065: No module named 'rasterio'
# Error at row 2066: No module named 'rasterio'
# Error at row 2067: No module named 'rasterio'
# Error at row 2068: No module named 'rasterio'
# Error at row 2069: No module named 'rasterio'
# Error at row 2070: No module named 'rasterio'
# Error at row 2071: No module named 'rasterio'
# Error at row 2072: No module named 'rasterio'
# Error at row 2073: No module named 'rasterio'
# Error at row 2074: No module named 'rasterio'
# Error at row 2075: No module named 'rasterio'
# Error at row 2076: No module named 'rasterio'
# Error at row 2077: No module named 'rasterio'
# Error at row 2078: No module named 'rasterio'
# Error at row 2079: No module named 'rasterio'
# Error at row 2080: No module named 'rasterio'
# Error at row 2081: No module named 'rasterio'
# Error at row 2082: No module named 'rasterio'
# Error at row 2083: No module named 'rasterio'
# Error at row 2084: No module named 'rasterio'
# Error at row 2085: No module named 'rasterio'
# Error at row 2086: No module named 'rasterio'
# Error at row 2087: No module named 'rasterio'
# Error at row 2088: No module named 'rasterio'
# Error at row 2089: No module named 'rasterio'
# Error at row 2090: No module named 'rasterio'
# Error at row 2091: No module named 'rasterio'
# Error at row 2092: No module named 'rasterio'
# Error at row 2093: No module named 'rasterio'
# Error at row 2094: No module named 'rasterio'
# Error at row 2095: No module named 'rasterio'
# Error at row 2096: No module named 'rasterio'
# Error at row 2097: No module named 'rasterio'
# Error at row 2098: No module named 'rasterio'
# Error at row 2099: No module named 'rasterio'
# Error at row 2100: No module named 'rasterio'
# Error at row 2101: No module named 'rasterio'
# Error at row 2102: No module named 'rasterio'
# Error at row 2103: No module named 'rasterio'
# Error at row 2104: No module named 'rasterio'
# Error at row 2105: No module named 'rasterio'
# Error at row 2106: No module named 'rasterio'
# Error at row 2107: No module named 'rasterio'
# Error at row 2108: No module named 'rasterio'
# Error at row 2109: No module named 'rasterio'
# Error at row 2110: No module named 'rasterio'
# Error at row 2111: No module named 'rasterio'
# Error at row 2112: No module named 'rasterio'
# Error at row 2113: No module named 'rasterio'
# Error at row 2114: No module named 'rasterio'
# Error at row 2115: No module named 'rasterio'
# Error at row 2116: No module named 'rasterio'
# Error at row 2117: No module named 'rasterio'
# Error at row 2118: No module named 'rasterio'
# Error at row 2119: No module named 'rasterio'
# Error at row 2120: No module named 'rasterio'
# Error at row 2121: No module named 'rasterio'
# Error at row 2122: No module named 'rasterio'
# Error at row 2123: No module named 'rasterio'
# Error at row 2124: No module named 'rasterio'
# Error at row 2125: No module named 'rasterio'
# Error at row 2126: No module named 'rasterio'
# Error at row 2127: No module named 'rasterio'
# Error at row 2128: No module named 'rasterio'
# Error at row 2129: No module named 'rasterio'
# Error at row 2130: No module named 'rasterio'
# Error at row 2131: No module named 'rasterio'
# Error at row 2132: No module named 'rasterio'
# Error at row 2133: No module named 'rasterio'
# Error at row 2134: No module named 'rasterio'
# Error at row 2135: No module named 'rasterio'
# Error at row 2136: No module named 'rasterio'
# Error at row 2137: No module named 'rasterio'
# Error at row 2138: No module named 'rasterio'
# Error at row 2139: No module named 'rasterio'
# Error at row 2140: No module named 'rasterio'
# Error at row 2141: No module named 'rasterio'
# Error at row 2142: No module named 'rasterio'
# Error at row 2143: No module named 'rasterio'
# Error at row 2144: No module named 'rasterio'
# Error at row 2145: No module named 'rasterio'
# Error at row 2146: No module named 'rasterio'
# Error at row 2147: No module named 'rasterio'
# Error at row 2148: No module named 'rasterio'
# Error at row 2149: No module named 'rasterio'
# Error at row 2150: No module named 'rasterio'
# Error at row 2151: No module named 'rasterio'
# Error at row 2152: No module named 'rasterio'
# Error at row 2153: No module named 'rasterio'
# Error at row 2154: No module named 'rasterio'
# Error at row 2155: No module named 'rasterio'
# Error at row 2156: No module named 'rasterio'
# Error at row 2157: No module named 'rasterio'
# Error at row 2158: No module named 'rasterio'
# Error at row 2159: No module named 'rasterio'
# Error at row 2160: No module named 'rasterio'
# Error at row 2161: No module named 'rasterio'
# Error at row 2162: No module named 'rasterio'
# Error at row 2163: No module named 'rasterio'
# Error at row 2164: No module named 'rasterio'
# Error at row 2165: No module named 'rasterio'
# Error at row 2166: No module named 'rasterio'
# Error at row 2167: No module named 'rasterio'
# Error at row 2168: No module named 'rasterio'
# Error at row 2169: No module named 'rasterio'
# Error at row 2170: No module named 'rasterio'
# Error at row 2171: No module named 'rasterio'
# Error at row 2172: No module named 'rasterio'
# Error at row 2173: No module named 'rasterio'
# Error at row 2174: No module named 'rasterio'
# Error at row 2175: No module named 'rasterio'
# Error at row 2176: No module named 'rasterio'
# Error at row 2177: No module named 'rasterio'
# Error at row 2178: No module named 'rasterio'
# Error at row 2179: No module named 'rasterio'
# Error at row 2180: No module named 'rasterio'
# Error at row 2181: No module named 'rasterio'
# Error at row 2182: No module named 'rasterio'
# Error at row 2183: No module named 'rasterio'
# Error at row 2184: No module named 'rasterio'
# Error at row 2185: No module named 'rasterio'
# Error at row 2186: No module named 'rasterio'
# Error at row 2187: No module named 'rasterio'
# Error at row 2188: No module named 'rasterio'
# Error at row 2189: No module named 'rasterio'
# Error at row 2190: No module named 'rasterio'
# Error at row 2191: No module named 'rasterio'
# Error at row 2192: No module named 'rasterio'
# Error at row 2193: No module named 'rasterio'
# Error at row 2194: No module named 'rasterio'
# Error at row 2195: No module named 'rasterio'
# Error at row 2196: No module named 'rasterio'
# Error at row 2197: No module named 'rasterio'
# Error at row 2198: No module named 'rasterio'
# Error at row 2199: No module named 'rasterio'
# Error at row 2200: No module named 'rasterio'
# Error at row 2201: No module named 'rasterio'
# Error at row 2202: No module named 'rasterio'
# Error at row 2203: No module named 'rasterio'
# Error at row 2204: No module named 'rasterio'
# Error at row 2205: No module named 'rasterio'
# Error at row 2206: No module named 'rasterio'
# Error at row 2207: No module named 'rasterio'
# Error at row 2208: No module named 'rasterio'
# Error at row 2209: No module named 'rasterio'
# Error at row 2210: No module named 'rasterio'
# Error at row 2211: No module named 'rasterio'
# Error at row 2212: No module named 'rasterio'
# Error at row 2213: No module named 'rasterio'
# Error at row 2214: No module named 'rasterio'
# Error at row 2215: No module named 'rasterio'
# Error at row 2216: No module named 'rasterio'
# Error at row 2217: No module named 'rasterio'
# Error at row 2218: No module named 'rasterio'
# Error at row 2219: No module named 'rasterio'
# Error at row 2220: No module named 'rasterio'
# Error at row 2221: No module named 'rasterio'
# Error at row 2222: No module named 'rasterio'
# Error at row 2223: No module named 'rasterio'
# Error at row 2224: No module named 'rasterio'
# Error at row 2225: No module named 'rasterio'
# Error at row 2226: No module named 'rasterio'
# Error at row 2227: No module named 'rasterio'
# Error at row 2228: No module named 'rasterio'
# Error at row 2229: No module named 'rasterio'
# Error at row 2230: No module named 'rasterio'
# Error at row 2231: No module named 'rasterio'
# Error at row 2232: No module named 'rasterio'
# Error at row 2233: No module named 'rasterio'
# Error at row 2234: No module named 'rasterio'
# Error at row 2235: No module named 'rasterio'
# Error at row 2236: No module named 'rasterio'
# Error at row 2237: No module named 'rasterio'
# Error at row 2238: No module named 'rasterio'
# Error at row 2239: No module named 'rasterio'
# Error at row 2240: No module named 'rasterio'
# Error at row 2241: No module named 'rasterio'
# Error at row 2242: No module named 'rasterio'
# Error at row 2243: No module named 'rasterio'
# Error at row 2244: No module named 'rasterio'
# Error at row 2245: No module named 'rasterio'
# Error at row 2246: No module named 'rasterio'
# Error at row 2247: No module named 'rasterio'
# Error at row 2248: No module named 'rasterio'
# Error at row 2249: No module named 'rasterio'
# Error at row 2250: No module named 'rasterio'
# Error at row 2251: No module named 'rasterio'
# Error at row 2252: No module named 'rasterio'
# Error at row 2253: No module named 'rasterio'
# Error at row 2254: No module named 'rasterio'
# Error at row 2255: No module named 'rasterio'
# Error at row 2256: No module named 'rasterio'
# Error at row 2257: No module named 'rasterio'
# Error at row 2258: No module named 'rasterio'
# Error at row 2259: No module named 'rasterio'
# Error at row 2260: No module named 'rasterio'
# Error at row 2261: No module named 'rasterio'
# Error at row 2262: No module named 'rasterio'
# Error at row 2263: No module named 'rasterio'
# Error at row 2264: No module named 'rasterio'
# Error at row 2265: No module named 'rasterio'
# Error at row 2266: No module named 'rasterio'
# Error at row 2267: No module named 'rasterio'
# Error at row 2268: No module named 'rasterio'
# Error at row 2269: No module named 'rasterio'
# Error at row 2270: No module named 'rasterio'
# Error at row 2271: No module named 'rasterio'
# Error at row 2272: No module named 'rasterio'
# Error at row 2273: No module named 'rasterio'
# Error at row 2274: No module named 'rasterio'
# Error at row 2275: No module named 'rasterio'
# Error at row 2276: No module named 'rasterio'
# Error at row 2277: No module named 'rasterio'
# Error at row 2278: No module named 'rasterio'
# Error at row 2279: No module named 'rasterio'
# Error at row 2280: No module named 'rasterio'
# Error at row 2281: No module named 'rasterio'
# Error at row 2282: No module named 'rasterio'
# Error at row 2283: No module named 'rasterio'
# Error at row 2284: No module named 'rasterio'
# Error at row 2285: No module named 'rasterio'
# Error at row 2286: No module named 'rasterio'
# Error at row 2287: No module named 'rasterio'
# Error at row 2288: No module named 'rasterio'
# Error at row 2289: No module named 'rasterio'
# Error at row 2290: No module named 'rasterio'
# Error at row 2291: No module named 'rasterio'
# Error at row 2292: No module named 'rasterio'
# Error at row 2293: No module named 'rasterio'
# Error at row 2294: No module named 'rasterio'
# Error at row 2295: No module named 'rasterio'
# Error at row 2296: No module named 'rasterio'
# Error at row 2297: No module named 'rasterio'
# Error at row 2298: No module named 'rasterio'
# Error at row 2299: No module named 'rasterio'
# Error at row 2300: No module named 'rasterio'
# Error at row 2301: No module named 'rasterio'
# Error at row 2302: No module named 'rasterio'
# Error at row 2303: No module named 'rasterio'
# Error at row 2304: No module named 'rasterio'
# Error at row 2305: No module named 'rasterio'
# Error at row 2306: No module named 'rasterio'
# Error at row 2307: No module named 'rasterio'
# Error at row 2308: No module named 'rasterio'
# Error at row 2309: No module named 'rasterio'
# Error at row 2310: No module named 'rasterio'
# Error at row 2311: No module named 'rasterio'
# Error at row 2312: No module named 'rasterio'
# Error at row 2313: No module named 'rasterio'
# Error at row 2314: No module named 'rasterio'
# Error at row 2315: No module named 'rasterio'
# Error at row 2316: No module named 'rasterio'
# Error at row 2317: No module named 'rasterio'
# Error at row 2318: No module named 'rasterio'
# Error at row 2319: No module named 'rasterio'
# Error at row 2320: No module named 'rasterio'
# X_data length: 0

# %%
X = torch.tensor(X_data, dtype=torch.float32, requires_grad=True)
y = torch.tensor(y_data, dtype=torch.float32).view(-1, 1)

# %%
# === DEFINE PINN ===
class PINN(nn.Module):
    def __init__(self, in_dim=8, hidden_dim=64, out_dim=1):
        super(PINN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, out_dim)
        )
    def forward(self, x):
        return self.net(x)

# %%
def physics_residual(model, inputs):
    x = inputs[:, 0:1].clone().detach().requires_grad_(True)
    y = inputs[:, 1:2].clone().detach().requires_grad_(True)
    slope = inputs[:, 2:3]
    elev = inputs[:, 3:4]
    cnn_feats = inputs[:, 4:]
    input_var = torch.cat([x, y, slope, elev, cnn_feats], dim=1).requires_grad_(True)
    u = model(input_var)
    grad_u = autograd.grad(u, input_var, grad_outputs=torch.ones_like(u), create_graph=True)[0]
    du_dx = grad_u[:, 0:1]
    du_dy = grad_u[:, 1:2]
    d2u_dx2 = autograd.grad(du_dx, input_var, grad_outputs=torch.ones_like(du_dx), create_graph=True)[0][:, 0:1]
    d2u_dy2 = autograd.grad(du_dy, input_var, grad_outputs=torch.ones_like(du_dy), create_graph=True)[0][:, 1:2]
    laplacian_u = d2u_dx2 + d2u_dy2
    D = cnn_feats[:, 0:1]
    vx = cnn_feats[:, 3:4] * slope
    vy = cnn_feats[:, 3:4] * slope
    advection = vx * du_dx + vy * du_dy
    diffusion = D * laplacian_u
    residual = -(diffusion + advection)
    return torch.mean(residual**2)

# %%
# === TRAINING ===
model = PINN()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
mse_loss = nn.MSELoss()
data_losses, physics_losses, total_losses = [], [], []

# %%
for epoch in range(1000):
    optimizer.zero_grad()
    pred = model(X)
    data_loss = mse_loss(pred, y)
    physics_loss = physics_residual(model, X)
    loss = data_loss + 0.5 * physics_loss
    loss.backward()
    optimizer.step()
    data_losses.append(data_loss.item())
    physics_losses.append(physics_loss.item())
    total_losses.append(loss.item())
    if epoch % 100 == 0:
        print(f"Epoch {epoch} | Data Loss: {data_loss.item():.6f} | Physics Loss: {physics_loss.item():.6f} | Total: {loss.item():.6f}")

# %%
# === EVALUATION ===
with torch.no_grad():
    y_pred = model(X).numpy()

# %%
r2 = r2_score(y.numpy(), y_pred)
print(f"R² Score: {r2:.4f}")

# %%
# === PLOTS ===
plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.scatter(y.numpy(), y_pred, alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
plt.xlabel("True Spread Rate")
plt.ylabel("Predicted Spread Rate")
plt.title(f"PINN Spread Rate Prediction (R² = {r2:.4f})")
plt.grid(True)

# %%
plt.subplot(2, 2, 2)
plt.semilogy(data_losses, label='Data Loss')
plt.semilogy(physics_losses, label='Physics Loss')
plt.semilogy(total_losses, label='Total Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.title("Training Losses")

# %%
plt.subplot(2, 2, 3)
residuals = y.numpy() - y_pred
plt.scatter(y_pred, residuals, alpha=0.6)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel("Predicted Spread Rate")
plt.ylabel("Residual")
plt.title("Residual Plot")
plt.grid(True)

# %%
plt.subplot(2, 2, 4)
plt.hist(residuals, bins=30)
plt.xlabel("Residual Value")
plt.ylabel("Frequency")
plt.title("Residual Histogram")
plt.grid(True)

# %%
plt.tight_layout()
plt.savefig("pinn_results.png")
plt.show()

# %%
torch.save(model.state_dict(), 'pinn_fire_spread_model.pth')
print("Model saved successfully.")
